# %% [markdown]
# <a href="https://colab.research.google.com/github/akso1234/DL/blob/main/inclass/03_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### KNN(K-Nearest Neighbors)

# %% [markdown]
# import library & read csv data

# %%
# library & data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
# from sklearn.datasets import load_iris
# iris = load_iris()

# column of dataset
# names = ['Sepal-length', 'Sepal-width', 'Petal-length', 'Petal-width', 'Species']
# dataset = pd.read_csv('/content/dmu_data/Iris.csv')
dataset = pd.read_csv('../content/sample_data/Data_all/Iris.csv')

# %% [markdown]
# search of data

# %%
dataset
# print(dataset)

# dataset.info()
# dataset.describe()

# dataset.head(5)
# dataset.tail()

# dataset.columns
# dataset.shape
# dataset.dtypes

# dataset.isnull().sum()
# Out:
#       Id  sepal-length  sepal-width  petal-length  petal-width         species
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 1      2           4.9          3.0           1.4          0.2     Iris-setosa
# 2      3           4.7          3.2           1.3          0.2     Iris-setosa
# 3      4           4.6          3.1           1.5          0.2     Iris-setosa
# 4      5           5.0          3.6           1.4          0.2     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
# training과 test dataset 분리
# (데이터셋이 달라 값을 다르게 지정하였습니다.)
X = dataset.iloc[:, :4].values # 모든 행은 사용하지만 열(칼럼)은 뒤에서 하나를 뺀 값을 가져와서 X에 저장
y = dataset.iloc[1:, 5].values # 모든 행은 사용하지만, 열은 앞에서 다섯 번째 값만 가져와서 y에 저장

# X.shape
X
# y.shape
# y
# Out:
# array([[  1. ,   5.1,   3.5,   1.4],
#        [  2. ,   4.9,   3. ,   1.4],
#        [  3. ,   4.7,   3.2,   1.3],
#        [  4. ,   4.6,   3.1,   1.5],
#        [  5. ,   5. ,   3.6,   1.4],
#        [  6. ,   5.4,   3.9,   1.7],
#        [  7. ,   4.6,   3.4,   1.4],
#        [  8. ,   5. ,   3.4,   1.5],
#        [  9. ,   4.4,   2.9,   1.4],
#        [ 10. ,   4.9,   3.1,   1.5],
#        [ 11. ,   5.4,   3.7,   1.5],
#        [ 12. ,   4.8,   3.4,   1.6],
#        [ 13. ,   4.8,   3. ,   1.4],
#        [ 14. ,   4.3,   3. ,   1.1],
#        [ 15. ,   5.8,   4. ,   1.2],
#        [ 16. ,   5.7,   4.4,   1.5],
#        [ 17. ,   5.4,   3.9,   1.3],
#        [ 18. ,   5.1,   3.5,   1.4],
#        [ 19. ,   5.7,   3.8,   1.7],
#        [ 20. ,   5.1,   3.8,   1.5],
#        [ 21. ,   5.4,   3.4,   1.7],
#        [ 22. ,   5.1,   3.7,   1.5],
#        [ 23. ,   4.6,   3.6,   1. ],
#        [ 24. ,   5.1,   3.3,   1.7],
#        [ 25. ,   4.8,   3.4,   1.9],
# ...
